# %%
import matplotlib.pyplot as plt
import numpy as np

import kwave.data
from kwave.kWaveSimulation import SimulationOptions
from kwave.kgrid import kWaveGrid
from kwave.kmedium import kWaveMedium
from kwave.ksensor import kSensor
from kwave.ksource import kSource
from kwave.kspaceFirstOrder3D import kspaceFirstOrder3DC
from kwave.options.simulation_execution_options import SimulationExecutionOptions
from kwave.utils.kwave_array import kWaveArray
from kwave.utils.plot import voxel_plot
from kwave.utils.signals import tone_burst
from kwave.utils.colormap import get_color_map

# %%
# Define constants
c0 = 1500
rho0 = 1000
source_f0 = 1e6
source_amp = 1e6
source_cycles = 5
source_focus = 20e-3
element_num = 6
element_width = 1e-3
element_length = 10e-3
element_pitch = 2e-3
translation = kwave.data.Vector([5e-3, 0, 8e-3])
rotation = kwave.data.Vector([0, 0, 0])
grid_size_x = 40e-3
grid_size_y = 20e-3
grid_size_z = 40e-3
ppw = 5
t_end = 35e-6
cfl = 0.5

# %%
# %%capture
# GRID
dx = c0 / (ppw * source_f0)
Nx = round(grid_size_x / dx)
Ny = round(grid_size_y / dx)
Nz = round(grid_size_z / dx)
kgrid = kWaveGrid([Nx, Ny, Nz], [dx, dx, dx])
kgrid.makeTime(c0, cfl, t_end)

# %%
# SOURCE
if element_num % 2 != 0:
    ids = np.arange(1, element_num + 1) - np.ceil(element_num / 2)
else:
    ids = np.arange(1, element_num + 1) - (element_num + 1) / 2

time_delays = -(np.sqrt((ids * element_pitch) ** 2 + source_focus ** 2) - source_focus) / c0
time_delays = time_delays - min(time_delays)

source_sig = source_amp * tone_burst(1 / kgrid.dt, source_f0, source_cycles,
                                      signal_offset=np.round(time_delays / kgrid.dt).astype(int))
karray = kWaveArray(bli_tolerance=0.05, upsampling_rate=10)

for ind in range(element_num):
    x_pos = 0 - (element_num * element_pitch / 2 - element_pitch / 2) + ind * element_pitch
    karray.add_rect_element([x_pos, 0, kgrid.z_vec[0][0]], element_width, element_length, rotation)
    karray.add_annular_array([x_pos, 0, kgrid.z_vec[0][0]],10e-3,([30e-3,0],[20e-3,0]),[50e-3,50e-3, 0])

karray.set_array_position(translation, rotation)
source = kSource()
source.p_mask = karray.get_array_binary_mask(kgrid)

# %matplotlib inline
voxel_plot(np.single(source.p_mask))
source.p = karray.get_distributed_source_signal(kgrid, source_sig)
# Out:
# /home/yokay/anaconda3/envs/kwave/lib/python3.12/site-packages/kwave/utils/kwave_array.py:137: RuntimeWarning: invalid value encountered in arcsin
#   varphi_min = arcsin(diameters[el_ind][0] / (2 * radius))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 21
#      19 karray.set_array_position(translation, rotation)
#      20 source = kSource()
# ---> 21 source.p_mask = karray.get_array_binary_mask(kgrid)
#      22 get_ipython().run_line_magic('matplotlib', 'inline')
#      23 voxel_plot(np.single(source.p_mask))
#
# File /home/yokay/anaconda3/envs/kwave/lib/python3.12/site-packages/kwave/utils/kwave_array.py:432, in kWaveArray.get_array_binary_mask(self, kgrid)
#     429 mask = np.squeeze(np.zeros((kgrid.Nx, kgrid.Ny, max(kgrid.Nz, 1)), dtype=bool))
#     431 for ind in range(self.number_elements):
# --> 432     grid_weights = self.get_off_grid_points(kgrid, ind, True)
#     433     mask = np.bitwise_or(np.squeeze(mask), grid_weights)
#     435 return mask
#
# File /home/yokay/anaconda3/envs/kwave/lib/python3.12/site-packages/kwave/utils/kwave_array.py:471, in kWaveArray.get_off_grid_points(self, kgrid, element_num, mask_only)
#     468     m_integration = self.elements[element_num].integration_points.shape[1]
#     469 else:
#     470     # compute the number of integration points using the upsampling rate
# --> 471     m_integration = ceil(m_grid * self.upsampling_rate)
#     473 # compute integration points covering element
#     474 if self.elements[element_num].type == "annulus":
#     475     # compute points using make_cart_spherical_segment
#
# ValueError: cannot convert float NaN to integer

# %%
# MEDIUM
medium = kWaveMedium(sound_speed=c0, density=rho0)

# %%
# SENSOR
sensor_mask = np.zeros((Nx, Ny, Nz))
sensor_mask[:, Ny // 2, :] = 1
sensor = kSensor(sensor_mask, record=['p_max'])

# %%
# SIMULATION
simulation_options = SimulationOptions(
    pml_auto=True,
    pml_inside=False,
    save_to_disk=True,
    data_cast='single',
)

execution_options = SimulationExecutionOptions(is_gpu_simulation=True)

sensor_data = kspaceFirstOrder3DC(kgrid=kgrid, medium=medium, source=source, sensor=sensor,
                                  simulation_options=simulation_options, execution_options=execution_options)

p_max = np.reshape(sensor_data['p_max'], (Nx, Nz), order='F')
# Out:
# C:\Users\yokay\AppData\Roaming\Python\Python312\site-packages\kwave\options\simulation_execution_options.py:111: UserWarning: Custom binary name set. Ignoring `is_gpu_simulation` state.
#   warnings.warn("Custom binary name set. Ignoring `is_gpu_simulation` state.")
# +---------------------------------------------------------------+
# |                   kspaceFirstOrder-OMP v1.3                   |
# +---------------------------------------------------------------+
# | Reading simulation configuration:                        Done |
# | Number of CPU threads:                                      4 |
# | Processor name:           12th Gen Intel(R) Core(TM) i5-12500 |
# +---------------------------------------------------------------+
# |                      Simulation details                       |
# +---------------------------------------------------------------+
# | Domain dimensions:                            175 x 125 x 175 |
# | Medium type:                                               3D |
# | Simulation time steps:                                    351 |
# +---------------------------------------------------------------+
# |                        Initialization                         |
# +---------------------------------------------------------------+
# | Memory allocation:                                       Done |
# | Data loading:                                            Done |
# | Elapsed time:                                           0.01s |
# +---------------------------------------------------------------+
# | FFT plans creation:                                      Done |
# | Pre-processing phase:                                    Done |
# | Elapsed time:                                           0.00s |
# +---------------------------------------------------------------+
# |                    Computational resources                    |
# +---------------------------------------------------------------+
# | Current host memory in use:                             268MB |
# | Expected output file size:                                0MB |
# +---------------------------------------------------------------+
# |                          Simulation                           |
# +----------+----------------+--------------+--------------------+
# | Progress |  Elapsed time  |  Time to go  |  Est. finish time  |
# +----------+----------------+--------------+--------------------+
# |     0%   |        0.337s  |     58.789s  |  23/01/25 10:05:04 |
# |     5%   |        2.746s  |     47.990s  |  23/01/25 10:04:56 |
# |    10%   |        5.338s  |     45.299s  |  23/01/25 10:04:56 |
# |    15%   |        7.761s  |     42.684s  |  23/01/25 10:04:56 |
# |    20%   |        9.937s  |     38.505s  |  23/01/25 10:04:54 |
# |    25%   |       11.861s  |     34.917s  |  23/01/25 10:04:52 |
# |    30%   |       13.830s  |     31.538s  |  23/01/25 10:04:51 |
# |    35%   |       15.978s  |     29.250s  |  23/01/25 10:04:51 |
# |    40%   |       18.322s  |     26.967s  |  23/01/25 10:04:50 |
# |    45%   |       20.768s  |     25.078s  |  23/01/25 10:04:52 |
# |    50%   |       23.193s  |     22.800s  |  23/01/25 10:04:51 |
# |    55%   |       25.951s  |     20.761s  |  23/01/25 10:04:52 |
# |    60%   |       27.911s  |     18.300s  |  23/01/25 10:04:52 |
# |    65%   |       30.401s  |     15.994s  |  23/01/25 10:04:51 |
# |    70%   |       32.203s  |     13.559s  |  23/01/25 10:04:51 |
# |    75%   |       34.072s  |     11.057s  |  23/01/25 10:04:51 |
# |    80%   |       36.081s  |      8.828s  |  23/01/25 10:04:50 |
# |    85%   |       38.036s  |      6.466s  |  23/01/25 10:04:50 |
# |    90%   |       39.918s  |      4.281s  |  23/01/25 10:04:50 |
# |    95%   |       41.905s  |      2.001s  |  23/01/25 10:04:50 |
# +----------+----------------+--------------+--------------------+
# | Elapsed time:                                          43.75s |
# +---------------------------------------------------------------+
# | Sampled data post-processing:                            Done |
# | Elapsed time:                                           0.00s |
# +---------------------------------------------------------------+
# |                            Summary                            |
# +---------------------------------------------------------------+
# | Peak memory in use:                                     270MB |
# +---------------------------------------------------------------+
# | Total execution time:                                  43.83s |
# +---------------------------------------------------------------+
# |                       End of computation                      |
# +---------------------------------------------------------------+

# %%
# VISUALISATION
plt.figure()
plt.imshow(1e-6 * p_max, extent=[1e3 * kgrid.x_vec[0][0], 1e3 * kgrid.x_vec[-1][0], 1e3 * kgrid.z_vec[0][0],
                                  1e3 * kgrid.z_vec[-1][0]], aspect='auto', cmap=get_color_map())
plt.xlabel('z-position [mm]')
plt.ylabel('x-position [mm]')
plt.title('Pressure Field')
plt.colorbar(label='[MPa]')
plt.show()
